# %%
# !pip3 show tweepy
# Out:
# Name: tweepy
# Version: 4.13.0
# Summary: Twitter library for Python
# Home-page: https://www.tweepy.org/
# Author: Joshua Roesslein
# Author-email: tweepy@googlegroups.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: oauthlib, requests, requests-oauthlib
# Required-by:

# %%
# !pip install tweepy

# %% [markdown]
# con una cuenta de twitter y creando una aplicación se pueden obtener las credenciales de acceso (consumer_key, consumer_secret, access_token y access_token_secret)

# %%
import tweepy
from tweepy import OAuthHandler
import pandas as pd

#keys
consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""

# Autenticación
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)


tweets = []

count = 5000

#por region Argentina:
#found_tweets = tweepy.Cursor(api.search, geocode="-38.416097,-63.61667,100km"):

#por region Argentina (radio 200 km) y palabra 'mujeres':
found_tweets = tweepy.Cursor(api.search_tweets, geocode="-32.926904,-60.727790,600km", q = 'nadie te quiere', tweet_mode='extended') #cambiar la palabra q por: insultos, grupos, etc.

for tweet in found_tweets.items(count):

    try:
        data = tweet.full_text
        tweets.append(data)

    except tweepy.TweepError as e:
        print(e.reason)
        continue

    except StopIteration:
        break

df = pd.DataFrame(tweets, columns=['Tweet'])

print(df)

df.to_csv('tweets2_negrademierda.csv')
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-8-52270bf3c0bd> in <cell line: 26>()
#      24 found_tweets = tweepy.Cursor(api.search_tweets, geocode="-32.926904,-60.727790,600km", q = 'nadie te quiere', tweet_mode='extended') #cambiar la palabra q por: insultos, grupos, etc.
#      25
# ---> 26 for tweet in found_tweets.items(count):
#      27
#      28     try:
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# ...

# %%
import tweepy

client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAANFvlgEAAAAALNnmDsPwJHUYVUU47qoA5819Tg0%3DuWIeKsxs8ng6OHPaUDQ3CZS1YHQ2HCAtPlphNw2LtMvX4agb1i')

# Replace with your own search query
query = 'feminazi place_country:AR'

# Replace with time period of your choice

file_name = 'tweets.txt'

with open(file_name, 'a+') as filehandle:
    for tweet in tweepy.Paginator(client.search_recent_tweets, query=query, geocode="-32.926904,-60.727790,600km",
                                  max_results=100):
        filehandle.write('%s\n' % tweet.text)
# Out:
# WARNING:tweepy.client:Unexpected parameter: geocode
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-8-fdc0df98ef4e> in <module>
#      11
#      12 with open(file_name, 'a+') as filehandle:
# ---> 13     for tweet in tweepy.Paginator(client.search_recent_tweets, query=query, geocode="-32.926904,-60.727790,600km",
#      14                                   max_results=100):
#      15         filehandle.write('%s\n' % tweet.text)
#
# /usr/local/lib/python3.8/dist-packages/tweepy/pagination.py in __next__(self)
#     124             self.kwargs["pagination_token"] = pagination_token
#     125
# --> 126         response = self.method(*self.args, **self.kwargs)
#     127
#     128         if isinstance(response, Response):
#
# /usr/local/lib/python3.8/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1264         """
# ...

# %%
import csv
import re

input_filenames = ['tweets2_feminazi.csv', 'tweets2_gordaputa.csv', 'tweets2_hijadeputa.csv', 'tweets2_incogible.csv', 'tweets2_matar puta.csv', 'tweets2_puta.csv', 'tweets2_putaconchuda.csv', 'tweets2_putamierda.csv', 'tweets2_putatevoya.csv', 'tweets2_temato.csv', 'tweets2_tevoyamatar.csv', 'tweets2_trola.csv', 'tweets2_violarforra.csv']


# Open the output CSV file
with open('cleaned2_tweets.csv', 'w', newline='') as output_file:
    writer = csv.writer(output_file)

    # Loop through each input file
    for input_filename in input_filenames:
        # Open the input CSV file
        with open(input_filename, 'r') as file:
            reader = csv.reader(file)

            # Loop through each row
            for row in reader:
                tweet = row[1]

                # Eliminate links
                tweet = re.sub(r'http\S+', '', tweet)

                # Eliminate @ mentions
                tweet = re.sub(r'@\S+', '', tweet)

                # Eliminate # hashtags
                tweet = re.sub(r'#\S+', '', tweet)

                # Eliminate #
                tweet = re.sub(r'#\S+', '', tweet)

                # Write the cleaned tweet to the output file
                writer.writerow([tweet])
                print(tweet)
# Out:
# Tweet
# Me ✨MENCIONAS✨ le mando JAJAJAJA 🤭
# A esa negra drogadicta de mierda no la menciono ni que tuviera que denunciarla por chorra.
# Una pinta de delincuente tiene.
# Anda a buscar tu vaso a la basura negra de mierda.//
#  Y me vas a decir que la mano que lo sostiene es gris tambien? O que la pared de un cuarto con la luz apagada es negra?? Obvio que es una iluminacion de mierda, pero la zapatilla es rosa con blanco.
# TROLA DE MIERDA negra que es
#  Así o negra lisa con números dorados, no podemos seguir con diseños tan sudacas de mierda
# Dan un paso lo suben al estado, van a cagar lo suben al estado BASTA NO QUIERO SABER LO Q HACES NEGRA DE MIERDA
# Estoy negra 🌚🥲
# Odio este calor de mierda!!
#   Pero quién te crees que sos para hablarme así, negra mugrienta. Fiera de mierda. Anda a hacete coger.
# lo más terrible d esto, es la pobre criatura. Que negra de mierda
# ...

# %%
import tweepy
from tweepy import OAuthHandler
import pandas as pd

#keys
consumer_key = ""
consumer_secret = ""
access_token= ""
access_token_secret= ""

# Autenticación
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)


tweets = []

count = 1000

#por region Argentina:
found_tweets = tweepy.Cursor(api.search, geocode="-38.416097,-63.61667,150km")

#por region Argentina (radio 200 km) y palabra mujer:
#found_tweets = tweepy.Cursor(api.search, geocode="-38.416097,-63.61667,200km", q = '')

for tweet in found_tweets.items(count):

    try:
        data = tweet.text
        tweets.append(data)

    except tweepy.TweepError as e:
        print(e.reason)
        continue

    except StopIteration:
        break

df = pd.DataFrame(tweets, columns=['Tweet'])

print(df)

df.to_csv('tweets_compras.csv')

# %% [markdown]
# ### Recopilacion de archivos y eliminacion de links menciones y hashtags

# %%
import csv
import re

input_filenames = ['tweets_compras.csv','tweets_.csv','tweets_guita.csv','tweets_lesbiana.csv']


# Open the output CSV file
with open('cleaned_tweets.csv', 'w', newline='') as output_file:
    writer = csv.writer(output_file)

    # Loop through each input file
    for input_filename in input_filenames:
        # Open the input CSV file
        with open(input_filename, 'r') as file:
            reader = csv.reader(file)

            # Loop through each row
            for row in reader:
                tweet = row[1]

                # Eliminate links
                tweet = re.sub(r'http\S+', '', tweet)

                # Eliminate @ mentions
                tweet = re.sub(r'@\S+', '', tweet)

                # Eliminate # hashtags
                tweet = re.sub(r'#\S+', '', tweet)

                # Eliminate #
                tweet = re.sub(r'#\S+', '', tweet)

                # Write the cleaned tweet to the output file
                writer.writerow([tweet])
                print(tweet)
# Out:
# Tweet
#    Ese es el feminismo de Uds, atacando a otras mujeres por simplemente tener diferencias entre ser feminazi y ser mujer, seguro que andarias a los abrazos con la madre de Lucio, vos.
#   El término feminazi es el que describe de la mejor manera al feminismo actual
#  A) Incomprobable.
# B) Feminazi.
# C) Fulera...muy fulera...30 kg fulera.
#
# No puedo creer el nivel mierda de C5K 🤮 La boluda feminazi diciendo que es violación a los DDHH que le den 50 años a los 8 asesinos.
# Mientras tanto aprovechan el caso Fernando para pegarle a la Corte Suprema. Vergonzoso ver este "periodismo"
# Se hizo justicia!
# No comprendo dónde  oye un cántico  nazi ahí. Son inferencias suyas. Ud. es de los que utilizan el término  "feminazi" para desprestigiar a cualquier opinión  feminista. Eso es un trabajo de la derecha rancia desde hace añares que nace para despreciar a aquellas mujeres que
# ...

# %% [markdown]
# Despues de esta primera limpieza elimine tweets de bots a mano

# %% [markdown]
# ### Eliminacion de repetidos y espacios

# %%
import openpyxl
import csv
import re

doc='cleaned_tweets.xlsx'
first_cell='A1'
last_cell= 'A1875'
phrases = []
count = 0
excel_document = openpyxl.load_workbook(doc, data_only=True)
first_sheet = excel_document.sheetnames[0]
sheet = excel_document[first_sheet]
for row in sheet[first_cell:last_cell]:
    for cell in row:
        if cell.value and cell.value != ' ' and cell.value :  # si la celda tiene informacion
            phrases.append(cell.value)
tweets_unicos = set(phrases)
with open('cleaned_tweets.csv', 'w', newline='') as output_file:
    writer = csv.writer(output_file)
    for tweet in tweets_unicos:
      writer.writerow([tweet])
      count = count + 1

print(count)
# Out:
# 1831
